# %%
import pandas as pd
from config import CONFIGS
import os
import re
import json

from utils.nlp_functions import initial_components_processing, build_sentiment_elements, filter_stopwords, strip_special_chars_and_lower
 
from typing import Tuple

import json

# hide warnings
import warnings
warnings.filterwarnings("ignore")

ENVIRONMENT = os.environ.get("ENVIRONMENT", "dev")
S3_SCRAPER_BUCKET = CONFIGS["s3_scraper_bucket"]
GAME_CONFIGS = CONFIGS["games"]
RATINGS_CONFIGS = CONFIGS["ratings"]
IS_LOCAL = True if os.environ.get("IS_LOCAL", "False").lower() == "true" else False

replacement_dictionary_path = 'data/prod/games/similarity_files/replacement_dictionary.json'
replacement_dictionary = json.load(open(replacement_dictionary_path))
replace_dict = replacement_dictionary['direct_replacements']
major_category_dict = replacement_dictionary['major_category_cleaning']
strip_list = replacement_dictionary['words_to_strip_all_right']

data_dir = 'data/prod/games/similarity_files/'
# Out:
# IS_LOCAL: True
#
# Checking for local config file and evaluating for updates from S3.
# Loading config from local

# %%
df = pd.read_pickle(f'{data_dir}top_1000_with_attached_rag.pkl')
desired_columns = ['BGGId','Name','Description']+[x for x in df.columns if 'generated' in x]

desc_df = df[desired_columns]
# desc_df.head()

# %%
desc_df['Description'] = desc_df['Description'].apply(lambda x: initial_components_processing(x, replace_dict))
desc_df['Description'] = desc_df['Description'].apply(filter_stopwords)
desc_df['Description'] = desc_df['Description'].apply(strip_special_chars_and_lower)

desc_df['generated_description'] = desc_df['generated_description'].apply(lambda x: initial_components_processing(x, replace_dict))
desc_df['generated_description'] = desc_df['generated_description'].apply(filter_stopwords)
desc_df['generated_description'] = desc_df['generated_description'].apply(strip_special_chars_and_lower)
desc_df.head()
# Out:
#         BGGId                                      Name  \
# 10174  224517                         Brass: Birmingham
# 4846   161936                 Pandemic Legacy: Season 1
# 5989   174430                                Gloomhaven
# 19051  342942                                  Ark Nova
# 20469  363622  The Castles of Burgundy: Special Edition
#
#                                              Description  \
# 10174  brass birmingham economic strategy game sequel...
# 4846   pandemic legacy cooperative campaign game over...
# 5989   gloomhavenis game euroinspired tactical combat...
# 19051  ark nova plan design modern scientifically man...
# 20469  castles burgundy legendary board game design c...
#
#                                           generated_pros  \
# 10174   Strategic Depth: Many players appreciate the ...
# 4846    Engaging Storyline: The evolving narrative ke...
# 5989    Content Variety: The game offers an immense a...
# 19051   Engaging Theme: The zoo management theme is a...
# 20469   High Production Quality: The game boasts exce...
#
#                                           generated_cons  \
# 10174   Steep Learning Curve: Some players find the r...
# 4846    Complexity: Some players find the numerous ch...
# 5989    Setup Time: Many reviews mention that the gam...
# 19051   Lengthy Gameplay: Many reviews highlight that...
# 20469   Complexity for New Players: Some reviews ment...
#
#                                    generated_description
# 10174  game strategic economic simulation set industr...
# 4846   game cooperative board game players work toget...
# 5989   game cooperative tactical adventure combines e...
# 19051  game strategic board game players manage zoo f...
# 20469  game strategic board game revolves around deve...

# %%
components_positive = []
components_negative = []

components_positive.append(desc_df['generated_pros'].apply(lambda x: build_sentiment_elements(x, major_category_dict, strip_list)))
components_negative.append(desc_df['generated_cons'].apply(lambda x: build_sentiment_elements(x, major_category_dict, strip_list)))

desc_df['Positive_Components'] = [x[0] for x in components_positive[0]]
desc_df['Positive_Sentences']=  [x[1] for x in components_positive[0]]
desc_df['Negative_Components']= [x[0] for x in components_negative[0]]
desc_df['Negative_Sentences']=  [x[1] for x in components_negative[0]]

desc_df.head()
# Out:
#         BGGId                                      Name  \
# 10174  224517                         Brass: Birmingham
# 4846   161936                 Pandemic Legacy: Season 1
# 5989   174430                                Gloomhaven
# 19051  342942                                  Ark Nova
# 20469  363622  The Castles of Burgundy: Special Edition
#
#                                              Description  \
# 10174  brass birmingham economic strategy game sequel...
# 4846   pandemic legacy cooperative campaign game over...
# 5989   gloomhavenis game euroinspired tactical combat...
# 19051  ark nova plan design modern scientifically man...
# 20469  castles burgundy legendary board game design c...
#
#                                           generated_pros  \
# 10174   Strategic Depth: Many players appreciate the ...
# 4846    Engaging Storyline: The evolving narrative ke...
# 5989    Content Variety: The game offers an immense a...
# 19051   Engaging Theme: The zoo management theme is a...
# 20469   High Production Quality: The game boasts exce...
#
#                                           generated_cons  \
# 10174   Steep Learning Curve: Some players find the r...
# 4846    Complexity: Some players find the numerous ch...
# 5989    Setup Time: Many reviews mention that the gam...
# 19051   Lengthy Gameplay: Many reviews highlight that...
# 20469   Complexity for New Players: Some reviews ment...
#
#                                    generated_description  \
# 10174  game strategic economic simulation set industr...
# 4846   game cooperative board game players work toget...
# 5989   game cooperative tactical adventure combines e...
# 19051  game strategic board game players manage zoo f...
# 20469  game strategic board game revolves around deve...
#
#                                      Positive_Components  \
# 10174  [strategic depth, excellent design, player int...
# 4846   [engaging storyline, cooperative, replayabilit...
# 5989   [content variety, replayability, strategic dep...
# 19051  [engaging theme, creative mechanics, excellent...
# 20469  [excellent production quality, engaging mechan...
#
#                                       Positive_Sentences  \
# 10174  [strategic depth many players appreciate games...
# 4846   [engaging storyline evolving narrative keeps p...
# 5989   [content variety game offers immense amount co...
# 19051  [engaging theme zoo management theme appealing...
# 20469  [excellent production quality game boasts exce...
#
#                                      Negative_Components  \
# 10174  [steep learning curve, fiddly mechanics, varia...
# 4846   [complex, time commitment, group dependency, f...
# 5989   [setup, complex, pacing issues, excellent comm...
# 19051  [lengthy gameplay, luck factor, complex, analy...
# 20469  [complex for new players, setup, potential for...
#
#                                       Negative_Sentences
# 10174  [steep learning curve players find rules diffi...
# 4846   [complex players find numerous choices rules o...
# 5989   [setup many reviews mention game requires sign...
# 19051  [lengthy gameplay many reviews highlight game ...
# 20469  [complex for new players reviews mention game ...

# %% [markdown]
# ### Research problematic entries

# %%
problematic_entries = [373, 10, 136, 334, 214]
for problematic_entry in problematic_entries:
    print(f"\n\nEntry {problematic_entry}")
    print(desc_df.iloc[problematic_entry]['generated_pros'])
    print(desc_df.iloc[problematic_entry]['generated_cons'])
    print(desc_df.iloc[problematic_entry]['Positive_Components'])
    print(desc_df.iloc[problematic_entry]['Negative_Components'])
    print(desc_df.iloc[problematic_entry]['Positive_Sentences'])
    print(desc_df.iloc[problematic_entry]['Negative_Sentences'])
# Out:
# Entry 373
#  Decisionmaking: Players appreciate the numerous decisions that need to be made, enhancing engagement and strategic depth. Replayability: Many reviews highlight the game's replayability, with players enjoying multiple sessions and finding new strategies each time. Artwork and Components: The quality of the artwork and game components is often praised, contributing positively to the overall experience. Engaging Theme: The historical theme is noted as engaging, providing a backdrop that enhances the gameplay. Tactical Depth: Players find the tactical decisions meaningful, adding to the satisfaction of gameplay. Solid Mechanics: The mechanics are generally wellreceived, with some players noting a lightweight feel that makes it accessible.
#  Luck Factor: Several reviews mention a significant luck element, which can lead to frustrating experiences, especially if players draw unfavorable cards. Randomness: The game can feel random at times, which may detract from the strategic experience for some players. Dry Theme: Some players feel that the theme lacks depth, making the game feel somewhat uninspired. Tediousness: A few reviewers find certain aspects of the game tedious, which can affect overall enjoyment. Luck Mitigation: There are concerns about the lack of luck mitigation, leading to feelings of slogging through the game when luck does not favor a player. Generic Feel: Some players describe the game as generic, suggesting that it may not stand out among other titles in the genre.
# ['decision making', 'replayability', 'art', 'engaging theme', 'strategic depth', 'elegant mechanics']
# ['luck factor', 'randomness', 'dry theme', 'tediousness', 'luck mitigation', 'generic feel']
# ['decision making players appreciate numerous decisions need made enhancing engagement strategic depth', 'replayability many reviews highlight games replayability players enjoying multiple sessions finding new strategies time', 'art quality artwork game components often praised contributing positively overall experience', 'engaging theme historical theme noted engaging providing backdrop enhances gameplay', 'strategic depth players find tactical decisions meaningful adding satisfaction gameplay', 'elegant mechanics mechanics generally wellreceived players noting lightweight feel makes accessible']
# ['luck factor several reviews mention significant luck element lead frustrating experiences especially players draw unfavorable cards', 'randomness game feel random times may detract strategic experience players', 'dry theme players feel theme lacks depth making game feel somewhat uninspired', 'tediousness reviewers find certain aspects game tedious affect overall enjoyment', 'luck mitigation concerns lack luck mitigation leading feelings slogging game luck favor player', 'generic feel players describe game generic suggesting may stand among titles genre']
#
#
# Entry 10
#  Engaging Gameplay: Many players find the combat mechanics to be enjoyable and strategic, enhancing the overall experience. Character Progression: The sense of character development and progression is frequently praised, making players feel invested in their heroes. Great Value: Several reviews highlight the game's affordability compared to other similar titles, making it accessible to a wider audience. Replayability: The variety of scenarios and character classes offers a high replay value, keeping the game fresh and exciting. Cooperative Experience: The game fosters teamwork and collaboration, which many players appreciate, especially in group settings. Good Entry Point: It serves as an excellent introduction to the larger game series, appealing to both new and experienced players.
#  Complex Rules: Some players find the rules to be fiddly and not clearly explained, which can lead to confusion during gameplay. Pacing Issues: A few reviews mention that the game can feel slow or cumbersome, particularly in terms of setup and execution of turns. Not for Everyone: The cardbased mechanics and narrative elements may not appeal to all players, with some feeling that it lacks depth. Initial Hook: Several users noted that the game did not immediately capture their interest, requiring more time to fully appreciate. Solo Play Limitations: While some enjoy playing solo, others feel that the game is better suited for group play, which can limit its appeal for solo gamers.
# ['engaging gameplay', 'character progression', 'good value', 'replayability', 'cooperative', 'good entry point']
# ['complex rules', 'pacing issues', 'not for everyone', 'initial hook', 'solo']
# ['engaging gameplay many players find combat mechanics enjoyable strategic enhancing overall experience', 'character progression sense character development progression frequently praised making players feel invested heroes', 'good value several reviews highlight games affordability compared similar titles making accessible wider audience', 'replayability variety scenarios character classes offers high replay value keeping game fresh exciting', 'cooperative game fosters teamwork collaboration many players appreciate especially group settings', 'good entry point serves excellent introduction larger game series appealing new experienced players']
# ['complex rules players find rules fiddly clearly explained lead confusion gameplay', 'pacing issues reviews mention game feel slow cumbersome particularly terms setup execution turns', 'not for everyone cardbased mechanics narrative elements may appeal players feeling lacks depth', 'initial hook several users noted game immediately capture interest requiring time fully appreciate', 'solo enjoy playing solo others feel game better suited group play limit appeal solo gamers']
#
#
# Entry 136
#  Engaging Mechanics: Many players appreciate the unique combination of mechanisms, particularly the balance between shares and cash flow. High Replayability: The game offers a variety of maps and scenarios, keeping the experience fresh and exciting for repeated plays. Community Support: There is a dedicated following, which enhances the game's appeal through shared strategies and experiences. Strategic Depth: Players enjoy the challenge of making tight decisions and the satisfaction of building an efficient rail network. Competitive Nature: The game fosters a competitive environment, making it enjoyable for groups that thrive on strategic rivalry. Complexity: While some find it daunting, many players appreciate the depth and intricacy of the gameplay, which can lead to rewarding experiences.
#  Steep Learning Curve: New players often find the rules complex and challenging to grasp, which can lead to frustration during initial plays. TimeConsuming: The game can take a long time to play, which may deter those looking for quicker gaming sessions. Intense DecisionMaking: Some players feel overwhelmed by the number of decisions required each turn, leading to a sense of it feeling like "work." Variable Enjoyment: Experiences can vary significantly based on player mood and group dynamics, with some players feeling less engaged during certain sessions. Aesthetic Concerns: The visual presentation of the game has been described as unappealing by some, which can affect the overall enjoyment. Limited Player Count: The game may not be as enjoyable with fewer players, as it is designed to shine in larger, more competitive groups.
# ['engaging mechanics', 'excellent replayability', 'community', 'strategic depth', 'competitive nature', 'complex']
# ['steep learning curve', 'time consuming', 'intense decision making', 'variable enjoyment', 'aesthetic', 'limited player count']
# ['engaging mechanics many players appreciate unique combination mechanisms particularly balance shares cash flow', 'excellent replayability game offers variety maps scenarios keeping experience fresh exciting repeated plays', 'community dedicated following enhances games appeal shared strategies experiences', 'strategic depth players enjoy challenge making tight decisions satisfaction building efficient rail network', 'competitive nature game fosters competitive environment making enjoyable groups thrive strategic rivalry', 'complex find daunting many players appreciate depth intricacy gameplay lead rewarding experiences']
# ['steep learning curve new players often find rules complex challenging grasp lead frustration initial plays', 'time consuming game take long time play may deter looking quicker gaming sessions', 'intense decision making players feel overwhelmed number decisions required turn leading sense feeling like work', 'variable enjoyment experiences vary significantly based player mood group dynamics players feeling less engaged certain sessions', 'aesthetic visual presentation game described unappealing affect overall enjoyment', 'limited player count game may enjoyable fewer players designed shine larger competitive groups']
#
#
# Entry 334
#  Strategic Depth: Many players appreciate the variety of strategic options available, which keeps gameplay engaging and thoughtprovoking. Replayability: The game offers different strategies and outcomes, encouraging players to return for multiple sessions. Quick Gameplay: Some reviews highlight that the game can be played relatively quickly, making it suitable for groups looking for a fastpaced experience. Interesting Mechanics: The unique mechanics, such as the rondel system and economic interactions, are noted as enjoyable and innovative. Good for Groups: Several players recommend the game for groups, particularly enjoying it with 4 players for optimal balance and engagement.
#  Complex Rules: A common concern is the steep learning curve, with many players finding the rules difficult to grasp initially, which can lead to confusion during gameplay. Downtime: Some reviews mention that the game can experience significant downtime, especially with larger player counts, which may detract from the overall experience. Theme and Components: There are mixed feelings about the theme, with some players finding it dated or not intuitive. Additionally, the physical components, such as the wooden pieces, have been criticized for being cumbersome. Length of Play: A few players expressed concerns about the game feeling longer than expected, particularly if players are not familiar with the rules. Player Interaction: Some reviews indicate that the competitive nature can lead to frustration, especially for those who prefer less confrontational gameplay.
# ['strategic depth', 'replayability', 'fast gameplay', 'creative mechanics', 'good for groups']
# ['complex rules', 'downtime', 'thematic components', 'length of play', 'player interaction']
# ['strategic depth many players appreciate variety strategic options available keeps gameplay engaging thoughtprovoking', 'replayability game offers different strategies outcomes encouraging players return multiple sessions', 'fast gameplay reviews highlight game played relatively quickly making suitable groups looking fastpaced experience', 'creative mechanics unique mechanics rondel system economic interactions noted enjoyable innovative', 'good for groups several players recommend game groups particularly enjoying 4 players optimal balance engagement']
# ['complex rules common concern steep learning curve many players finding rules difficult grasp initially lead confusion gameplay', 'downtime reviews mention game experience significant downtime especially larger player counts may detract overall experience', 'thematic components mixed feelings theme players finding dated intuitive', 'length of play players expressed concerns game feeling longer expected particularly players familiar rules', 'player interaction reviews indicate competitive nature lead frustration especially prefer less confrontational gameplay']
#
#
# Entry 214
#  Engaging Gameplay: Many players find the game fun and full of potential, especially with the right group dynamics. Variety of Strategies: The unique alien powers allow for diverse strategies, keeping the game fresh and interesting. High Replay Value: Players appreciate the game's ability to offer different experiences with each session, particularly with expansions. Aesthetic Appeal: The game is noted for its attractive design and components, enhancing the overall experience. Social Interaction: The negotiation aspect fosters social interaction, making it a great choice for groups that enjoy collaborative play.
#  Group Dependency: The game heavily relies on the dynamics of the gaming group, which can lead to inconsistent experiences. Some players feel it may not work well with all groups. Balance Issues: There are concerns about unbalanced gameplay, where certain alien powers may overshadow others, leading to frustration. Complex Rules: New players may find the rules overwhelming, which can detract from the enjoyment of the game. Lengthy Playtime: Some reviews mention that the game can take a long time to play, which may deter players from bringing it to the table frequently. Arbitrary Feel: A few players expressed that the game can feel arbitrary at times, impacting their overall enjoyment.
# ['engaging gameplay', 'variable strategies', 'excellent replay value', 'aesthetic', 'social interaction']
# ['group dependency', 'balanced issues', 'complex rules', 'lengthy playtime', 'arbitrary feel']
# ['engaging gameplay many players find game fun full potential especially right group dynamics', 'variable strategies unique alien powers allow diverse strategies keeping game fresh interesting', 'excellent replay value players appreciate games ability offer different experiences session particularly expansions', 'aesthetic game noted attractive design components enhancing overall experience', 'social interaction negotiation aspect fosters social interaction making great choice groups enjoy collaborative play']
# ['group dependency game heavily relies dynamics gaming group lead inconsistent experiences', 'balanced issues concerns unbalanced gameplay certain alien powers may overshadow others leading frustration', 'complex rules new players may find rules overwhelming detract enjoyment game', 'lengthy playtime reviews mention game take long time play may deter players bringing table frequently', 'arbitrary feel players expressed game feel arbitrary times impacting overall enjoyment']

# %%
# find the entry with the most words in a component

max_len = 0
max_entry = ""

for i, row in desc_df.iterrows():
    row_sentences = row['Negative_Components']
    for sentence in row_sentences:
        if len(sentence.split()) > max_len:
            max_len = len(sentence.split())
            max_entry = i
            print(i, max_len, sentence)
# Out:
# 10174 3 steep learning curve
# 20469 4 complex for new players
# 16860 5 mixed experiences with player counts

# %% [markdown]
# ### Save File

# %%
desc_df = desc_df.drop(columns=['Name','generated_pros','generated_cons'])
desc_df = desc_df.rename(columns={'generated_description':'About'})
desc_df.to_pickle(f"{data_dir}top_1000_cleaned_rag.pkl")
desc_df.head()
# Out:
#         BGGId                                        Description  \
# 10174  224517  brass birmingham economic strategy game sequel...
# 4846   161936  pandemic legacy cooperative campaign game over...
# 5989   174430  gloomhavenis game euroinspired tactical combat...
# 19051  342942  ark nova plan design modern scientifically man...
# 20469  363622  castles burgundy legendary board game design c...
#
#                                                    About  \
# 10174  game strategic economic simulation set industr...
# 4846   game cooperative board game players work toget...
# 5989   game cooperative tactical adventure combines e...
# 19051  game strategic board game players manage zoo f...
# 20469  game strategic board game revolves around deve...
#
#                                      Positive_Components  \
# 10174  [strategic depth, excellent design, player int...
# 4846   [engaging storyline, cooperative, replayabilit...
# 5989   [content variety, replayability, strategic dep...
# 19051  [engaging theme, creative mechanics, excellent...
# 20469  [excellent production quality, engaging mechan...
#
#                                       Positive_Sentences  \
# 10174  [strategic depth many players appreciate games...
# 4846   [engaging storyline evolving narrative keeps p...
# 5989   [content variety game offers immense amount co...
# 19051  [engaging theme zoo management theme appealing...
# 20469  [excellent production quality game boasts exce...
#
#                                      Negative_Components  \
# 10174  [steep learning curve, fiddly mechanics, varia...
# 4846   [complex, time commitment, group dependency, f...
# 5989   [setup, complex, pacing issues, excellent comm...
# 19051  [lengthy gameplay, luck factor, complex, analy...
# 20469  [complex for new players, setup, potential for...
#
#                                       Negative_Sentences
# 10174  [steep learning curve players find rules diffi...
# 4846   [complex players find numerous choices rules o...
# 5989   [setup many reviews mention game requires sign...
# 19051  [lengthy gameplay many reviews highlight game ...
# 20469  [complex for new players reviews mention game ...

# %%
all_positive_components = []
all_negative_components = []

# raw_pro_components = desc_df['generated_pros'].apply(clean_field_to_integral_components)
# raw_negat_components = desc_df['generated_cons'].apply(clean_field_to_integral_components)

# for pos in raw_pro_components:
#     all_positive_components += pos

# for neg in raw_negat_components:
#     all_negative_components += neg

for pos in desc_df['Positive_Components']:
    all_positive_components += pos

for neg in desc_df['Negative_Components']:
    all_negative_components += neg

with open(f"{data_dir}major_positives.json", "w") as f:
    json.dump(all_positive_components, f)

with open (f"{data_dir}major_negatives.json", "w") as f:
    json.dump(all_negative_components, f)
